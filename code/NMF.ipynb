# %% [markdown]
# Initial imports of necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import time
from sklearn.metrics import accuracy_score,  f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA, NMF
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import precision_recall_fscore_support, log_loss
import random
import time
import collections
import warnings
from scipy.stats import pearsonr, spearmanr

# %matplotlib inline

# %% [markdown]
# Read in Train, Test and Label csv files as Pandas dataframes

# %%
train_tcga_df = pd.read_csv('../data/train_tcga_expression_matrix_processed.tsv', header=0, sep='\t')
test_tcga_df = pd.read_csv('../data/test_tcga_expression_matrix_processed.tsv', header=0, sep='\t')

labels_tcga_df = pd.read_csv('../data/tcga_sample_identifiers.tsv', header=0, sep='\t')

# %% [markdown]
# The final TCGA PanCanAtlas gene expression matrix with 11060 samples, which included 33 different cancer types, and 16148 genes.
#
# With a 90/10 train/test split, this results in 9954/1106 train test sample split, with 16149 cols (1 added col for 'sample_id')

# %% [markdown]
# Load first 5 samples in each of the dataframes to obtain a feel for the structure of the data

# %%
train_tcga_df.head()
# Out:
#          sample_id      1    10     100   1000   10000  10001  10002   10003  \
# 0  TCGA-LL-A73Z-01  202.0  28.5   329.0   84.5   492.0  448.0  4.590   14.70
# 1  TCGA-55-8207-01   77.5  22.5    74.5   13.1   784.0  333.0  2.540  176.00
# 2  TCGA-FF-A7CR-01  152.0   0.0  3020.0   26.6   486.0  497.0  0.000    8.47
# 3  TCGA-BK-A13C-11   80.5  40.0    70.6  284.0  2420.0  325.0  1.200   91.40
# 4  TCGA-EB-A6L9-06  319.0   0.0   422.0  184.0   423.0  392.0  0.945    2.36
#
#    100037417  ...    9987   9988    9989      999    9990    9991   9992  \
# 0      337.0  ...  3430.0  717.0  1800.0   6360.0   299.0  2310.0  10.60
# 1      153.0  ...  6050.0  923.0  2490.0  11300.0  1150.0  4030.0   9.08
# 2      348.0  ...  4930.0  897.0   861.0     39.7   464.0  3320.0   0.00
# 3      231.0  ...  3890.0  737.0  1410.0     10.9  1120.0  1990.0   5.24
# 4      585.0  ...  1930.0  328.0  1340.0   7010.0   450.0   563.0  10.90
#
#      9993   9994    9997
# 0  3190.0  337.0   892.0
# 1  2890.0  316.0   301.0
# 2  1330.0  606.0   558.0
# 3  3090.0  673.0   263.0
# 4  3780.0   37.3  1120.0
#
# [5 rows x 16149 columns]

# %%
test_tcga_df.head()
# Out:
#          sample_id     1     10     100     1000   10000  10001  10002  10003  \
# 0  TCGA-CN-5365-01  70.5  0.000  1310.0    18.70    73.9  757.0   1.82  10.50
# 1  TCGA-LP-A7HU-01  27.8  0.949   517.0     6.17    63.6  365.0   4.27   9.02
# 2  TCGA-22-5491-11  87.6  3.760    88.3    14.40   642.0  295.0   6.84  59.90
# 3  TCGA-CS-6667-01  75.8  0.000    55.6  2720.00  2170.0  281.0   3.90   9.57
# 4  TCGA-20-1684-01  63.1  0.703    75.2  4500.00   792.0  433.0   1.64   4.16
#
#    100037417  ...    9987    9988    9989      999    9990    9991   9992  \
# 0      414.0  ...  2730.0   612.0  5780.0  10400.0   879.0  3830.0   4.10
# 1      633.0  ...  4510.0   543.0  1360.0   4960.0   510.0  2220.0  17.60
# 2      159.0  ...  4420.0   479.0  2190.0   4480.0   870.0  2120.0   5.13
# 3      251.0  ...  5460.0  1550.0  1370.0     12.8  1430.0   601.0  23.70
# 4      623.0  ...  5200.0   812.0  1070.0   8410.0   505.0  1170.0  14.80
#
#      9993   9994    9997
# 0  4220.0  308.0  1300.0
# 1  2410.0  233.0   993.0
# 2  5030.0  285.0   530.0
# 3  7530.0  473.0   258.0
# 4  1910.0  281.0   221.0
#
# [5 rows x 16149 columns]

# %%
labels_tcga_df.head()
# Out:
#          sample_id          sample_type cancer_type
# 0  TCGA-02-0047-01  Primary Solid Tumor         GBM
# 1  TCGA-02-0055-01  Primary Solid Tumor         GBM
# 2  TCGA-02-2483-01  Primary Solid Tumor         GBM
# 3  TCGA-02-2485-01  Primary Solid Tumor         GBM
# 4  TCGA-02-2486-01  Primary Solid Tumor         GBM

# %% [markdown]
# Print shape of each of the dfs

# %%
print("Train df Shape", train_tcga_df.shape)
print("Test df Shape", test_tcga_df.shape)
print("Labels df Shape", labels_tcga_df.shape)
# Out:
# Train df Shape (9954, 16149)
# Test df Shape (1106, 16149)
# Labels df Shape (11060, 3)

# %% [markdown]
# Obtain the list of 'Sample ID' (Indicator Variable)  in each of the dataframes, and use them to append the cancer type (aka the Y variable) from the labels df onto the train and test df

# %%
train_id = train_tcga_df['sample_id']
test_id = test_tcga_df['sample_id']
label_id = labels_tcga_df['sample_id']

# %%
merge_train = []
merge_test = []

for i in train_id:
    val = labels_tcga_df.loc[labels_tcga_df['sample_id'] == i]
    merge_train.append(str(val['cancer_type']).split()[1])
    
for i in test_id:
    val = labels_tcga_df.loc[labels_tcga_df['sample_id'] == i]
    merge_test.append(str(val['cancer_type']).split()[1])

# %% [markdown]
# Create new col in train and test with the cancer type added in

# %%
train_tcga_df['cancer_type'] = merge_train
print(train_tcga_df.shape)
train_tcga_df.head()
# Out:
# (9954, 16150)
#          sample_id      1    10     100   1000   10000  10001  10002   10003  \
# 0  TCGA-LL-A73Z-01  202.0  28.5   329.0   84.5   492.0  448.0  4.590   14.70
# 1  TCGA-55-8207-01   77.5  22.5    74.5   13.1   784.0  333.0  2.540  176.00
# 2  TCGA-FF-A7CR-01  152.0   0.0  3020.0   26.6   486.0  497.0  0.000    8.47
# 3  TCGA-BK-A13C-11   80.5  40.0    70.6  284.0  2420.0  325.0  1.200   91.40
# 4  TCGA-EB-A6L9-06  319.0   0.0   422.0  184.0   423.0  392.0  0.945    2.36
#
#    100037417  ...   9988    9989      999    9990    9991   9992    9993  \
# 0      337.0  ...  717.0  1800.0   6360.0   299.0  2310.0  10.60  3190.0
# 1      153.0  ...  923.0  2490.0  11300.0  1150.0  4030.0   9.08  2890.0
# 2      348.0  ...  897.0   861.0     39.7   464.0  3320.0   0.00  1330.0
# 3      231.0  ...  737.0  1410.0     10.9  1120.0  1990.0   5.24  3090.0
# 4      585.0  ...  328.0  1340.0   7010.0   450.0   563.0  10.90  3780.0
#
#     9994    9997  cancer_type
# 0  337.0   892.0         BRCA
# 1  316.0   301.0         LUAD
# 2  606.0   558.0         DLBC
# 3  673.0   263.0         UCEC
# 4   37.3  1120.0         SKCM
#
# [5 rows x 16150 columns]

# %%
test_tcga_df['cancer_type'] = merge_test
print(test_tcga_df.shape)
test_tcga_df.head()
# Out:
# (1106, 16150)
#          sample_id     1     10     100     1000   10000  10001  10002  10003  \
# 0  TCGA-CN-5365-01  70.5  0.000  1310.0    18.70    73.9  757.0   1.82  10.50
# 1  TCGA-LP-A7HU-01  27.8  0.949   517.0     6.17    63.6  365.0   4.27   9.02
# 2  TCGA-22-5491-11  87.6  3.760    88.3    14.40   642.0  295.0   6.84  59.90
# 3  TCGA-CS-6667-01  75.8  0.000    55.6  2720.00  2170.0  281.0   3.90   9.57
# 4  TCGA-20-1684-01  63.1  0.703    75.2  4500.00   792.0  433.0   1.64   4.16
#
#    100037417  ...    9988    9989      999    9990    9991   9992    9993  \
# 0      414.0  ...   612.0  5780.0  10400.0   879.0  3830.0   4.10  4220.0
# 1      633.0  ...   543.0  1360.0   4960.0   510.0  2220.0  17.60  2410.0
# 2      159.0  ...   479.0  2190.0   4480.0   870.0  2120.0   5.13  5030.0
# 3      251.0  ...  1550.0  1370.0     12.8  1430.0   601.0  23.70  7530.0
# 4      623.0  ...   812.0  1070.0   8410.0   505.0  1170.0  14.80  1910.0
#
#     9994    9997  cancer_type
# 0  308.0  1300.0         HNSC
# 1  233.0   993.0         CESC
# 2  285.0   530.0         LUSC
# 3  473.0   258.0          LGG
# 4  281.0   221.0           OV
#
# [5 rows x 16150 columns]

# %% [markdown]
# To conserve RAM usage, we delete computed variables when are done using them. First we delete the labels matrix, as we have already appended cancer type to train and test matrices

# %%
del labels_tcga_df

# %% [markdown]
# Functions to return dataframe with only the presence or absence of a particular cancr type. We also shuffle the dataframe before returning it

# %%
def returnDf2(df, ind, c_type):
    '''
    df - input df to rename classes on (train_df or test_df)
    ind - either merge_train or merge_test
    c_type - cancer type we aim to detect 
    '''

    #drop sample_id (not needed as we have already appended the cancer type from labels)
    df2  = df.drop(['sample_id'], axis=1)

    #obtain proportion of c_type in the train set (for proper sampling)
    fraction = collections.Counter(merge_train)[c_type]/len(merge_train)

    #Set all elements not of c_type to 0
    df2_0 = df2[df2.cancer_type!=c_type]
    df2_0.loc[:,"cancer_type"] = 0

    #randomly select frac of the dataset (to have even split across the classes)
    # df2_0 = df2_0.sample(frac = fraction)

    #Set all elements of c_type to 1
    df2_1 = df2[df2.cancer_type==c_type]
    df2_1.loc[:,"cancer_type"] = 1

    #Create new df with samples, and ensure classification variable is of type int
    df2 = pd.concat([df2_0, df2_1])
    df2["cancer_type"] = df2["cancer_type"].astype('int')

    #Shuffle df2
    df2 = df2.sample(frac=1).reset_index(drop=True)

    return df2

# %% [markdown]
# Function to Perform Logistic Regression, and return accuracy and runtime of classifier

# %%
def runLR(df2, test2):

    #LR Classifier with 16148 feature dimensionality
    start_time = time.time()
    clf = LogisticRegression(random_state=0).fit(df2.iloc[:,:-1],df2["cancer_type"])
    pred = clf.predict(test2.iloc[:,:-1])
    LR_accuracy = accuracy_score(test2.cancer_type,pred)
    LR_computation_time = time.time() - start_time

    del clf

    return LR_accuracy, LR_computation_time

# %% [markdown]
# Function to recontruct original featureset from nmf scores and loadings

# %%
def compile_reconstruction(input_df,nmf_df,nmf,ctype,k,test=False):
        """
        Compile reconstruction costs between input and algorithm reconstruction
        Arguments:
        Two dictionaries storing 1) reconstruction costs and 2) reconstructed
        matrix for each algorithm
        nmf - NMF model
        nmf_df - matrix in nmf component space
        input_df - original featureset, used for setting values of col names in pandas
        """
        
        
        
        nmf_reconstruct_mat = nmf.inverse_transform(nmf_df)
        
        reconstruct_mat = pd.DataFrame(nmf_reconstruct_mat,
                                              index=input_df.index,
                                              columns=input_df.columns)

        return reconstruct_mat

# %% [markdown]
# Function to Scale Data before performing NMF. This Function scales data around a Gaussian (Normal) distribution, before shifting the distribution to ensure non-negative entries

# %%
def NMF_scale(df2,test2):
    '''
    df2 - train dataframe
    test2 - test dataframe
    '''

    #StandardScaler shifts data to follow Gaussian distribution
    standard_train = StandardScaler()
    result_train = standard_train.fit_transform(df2.iloc[:,:-1])
    result_train = pd.DataFrame(result_train)

    #MinMax shifts data to ensure no negative values
    scaler_train = MinMaxScaler()
    result_train=scaler_train.fit_transform(result_train.iloc[:,:-1])
    result_train = pd.DataFrame(result_train)
    

    #Repeat procedure for test dataframe
    standard_test = StandardScaler()
    result_test = standard_test.fit_transform(test2.iloc[:,:-1])
    result_test = pd.DataFrame(result_test)

    scaler_test = MinMaxScaler()
    result_test=scaler_test.fit_transform(result_test.iloc[:,:-1])
    result_test = pd.DataFrame(result_test)

    return result_train, result_test

# %% [markdown]
# Compute NMF on Scaled Data, and return reconstructed matrices, scores and computation time

# %%
def returnNMF(result_train, result_test, ctype, k):

    '''
    result_train - scaled train dataframe
    result_test - scaled test dataframe
    ctype - cancertype we aim to detect
    k - no. of components
    '''
    
    start_time = time.time()
    

    #ensure n_comp does not exceed no. of features
    n_comp= min(k, result_train.shape[0])

    # Define NMF Model
    nmf = NMF(n_components=n_comp)
    
    # NMF Model Fitting for Train Set
    nmf_comp_train = nmf.fit_transform(result_train)
    colnames = ['nmf_{}'.format(x) for x in range(0, n_comp)]

    #Store NMF matrix and weights in csv
    nmf_comp_train = pd.DataFrame(nmf_comp_train,
                               columns=colnames,index=result_train.index)
    
    nmf_weights_train = pd.DataFrame(nmf.components_,
                                        columns=result_train.columns,
                                        index=colnames)
    
    nmf_time = time.time()-start_time
    
    # NMF Transform on the Test Set
    nmf_comp_test = nmf.transform(result_test)
    nmf_comp_test = pd.DataFrame(nmf_comp_test,
                               columns=colnames,index=result_test.index)

    # compile reconstruction 
    reconstruct_mat_train = compile_reconstruction(result_train,nmf_comp_train ,nmf,ctype,k)
    reconstruct_mat_test = compile_reconstruction(result_test, nmf_comp_test, nmf,ctype,k)

    #Delete model to save RAM usage
    del nmf
    
    #return nmf scores from train and test, reconstruction from train and test, and computation time
    return reconstruct_mat_train, reconstruct_mat_test, nmf_comp_train, nmf_comp_test, nmf_time

# %% [markdown]
# Function to separate last col (cancer type) as Y variable for prediction

# %%
def prepNMFClassifier(df2, test2, nmf_comp_train, nmf_comp_test):
    '''
    df2 - train dataframe
    test2 - test dataframe
    nmf_comp_train - training scores matrix
    nmf_comp_test - test scores matrix
    '''

    #Detect last col from all input dataframes and matrices
    train_y= df2.cancer_type
    test_y=  test2.cancer_type
    
    train_x= nmf_comp_train.iloc[:,:-1]
    test_x = nmf_comp_test.iloc[:,:-1]
    
    return train_x,test_x,train_y,test_y

# %% [markdown]
# Function to perform Logistic Regression on nmf scores and compute accuracy, precision, recall, F1 score and computation Time

# %%
# LR model after NMF

def NMFClassifier(train_x, train_y, test_x, test_y):
    '''
    train_x - nmf scores of training matrix
    test_x - nmf scores of test matrix
    train_y - ground truth Y values for training
    test_y - ground truth Y values for test
    '''
    
    start_time = time.time()

    #perform LR and predict test values
    clf2 = LogisticRegression(random_state=0).fit(train_x,train_y)
    pred= clf2.predict(test_x)

    #compute accuracy metrics
    accuracy = accuracy_score(pred,test_y)
    precision, recall, f1score, _= precision_recall_fscore_support(test_y, pred)
    time_laps = time.time() - start_time

    #delete LR model to save RAM
    del clf2

    return accuracy, time_laps, precision[0], recall[0], f1score[0]

# %% [markdown]
# Function to calculate reconstruction loss after NMF

# %%
def calc_reconstruct_loss(input_df, reconstruct_mat): 
    '''
    input_df - original dataframe
    reconstruct_mat - reconstructed matrix after nmf
    '''
    
    loss = np.sum((input_df - reconstruct_mat) ** 2, axis=1).mean()
    
    return loss

# %% [markdown]
# Function to calculate pearson coefficient for each sample between the original and reconstructed matrices

# %%
def calc_pearson(input_df, reconstruct_mat):
    '''
    input_df - original dataframe
    reconstruct_mat - reconstructed matrix after nmf
    '''   
    
    r = [pearsonr(reconstruct_mat.iloc[x, :], input_df.iloc[x, :])[0] for x in range(input_df.shape[0])]

    
    return r

# %% [markdown]
# Function to calculate spearman coefficient for each sample between the original and reconstructed matrices

# %%
def calc_spearman(input_df, reconstruct_mat):
    '''
    input_df - original dataframe
    reconstruct_mat - reconstructed matrix after nmf
    '''
    s = [spearmanr(reconstruct_mat.iloc[x, :], input_df.iloc[x, :])[0] for x in range(input_df.shape[0])]

    return s

# %% [markdown]
# Cell to perform NMF data compression on the input dataframe for different values of k - the number of reduced components. This cell also performs one vs all classification by creating a new datafram for each value of k and c_type

# %%
#obtain all the different values of cancer types
c_type_list = collections.Counter(merge_train)

#Columns of resultant dataframe, and create it
cols = ['cancer_type', 'Full-data acc.', 'Full-data comp. time', 'NMF components', 'NMF calc. time', 'NMF acc.','Precision', 'Recall', 'F1Score', 'Train Reconstruction Loss','Test Reconstruction Loss', 'Pearson Coeff', 'Spearman Coeff']
results_df = pd.DataFrame(columns = cols)
i = 0

#List of different values of k
num_latent_space= [2,5,10,20,50,100]

#Define empty lists to hold results in
k_loss_test =[]
class_wise_loss_test=[]

k_loss_train =[]
class_wise_loss_train=[]

class_wise_pearson=[]

class_wise_spearman=[]

#Outer loop with number of reduced dimensions
for k in num_latent_space:

    #more empty lists to hold values fro each individual cancer type
    class_loss_test=[]
    class_loss_train=[]

    class_pearson = []

    class_spearman = []

    #Inner loop for different cancer types
    for c_type in c_type_list:

        print(str(k) + ", " + c_type)
        # train_data
        df2 = returnDf2(train_tcga_df, merge_train, c_type)
        #test data
        test2 = returnDf2(test_tcga_df, merge_test, c_type)
        # run LR on Entire datasaet 
        accuracy, time_laps = runLR(df2, test2)

        result_train, result_test = NMF_scale(df2, test2)
        
        # calculate NMF and reconstruction 
        reconstruct_mat_train, reconstruct_mat_test, nmf_comp_train, nmf_comp_test, nmf_time = returnNMF(result_train, result_test, c_type, k)
        
        # get train test split
        train_x,test_x,train_y,test_y = prepNMFClassifier(df2, test2, nmf_comp_train, nmf_comp_test)
        
        # run LR on nmf components
        nmf_acc, nmf_time, precision, recall, f1score = NMFClassifier(train_x, train_y, test_x, test_y)

        #Calculate data reduction metrics
        loss_train=calc_reconstruct_loss(result_train, reconstruct_mat_train)
        class_loss_train.append(loss_train)

        loss_test=calc_reconstruct_loss(result_test, reconstruct_mat_test)
        class_loss_test.append(loss_test)

        pearson=calc_pearson(result_test, reconstruct_mat_test)
        class_pearson.append(pearson)

        spearman=calc_spearman(result_test, reconstruct_mat_test)
        class_spearman.append(spearman)

        #Append all results to dataframe
        results_df.loc[i] = [c_type, accuracy,time_laps, nmf_comp_test.shape[1],nmf_time,  nmf_acc,precision, recall, f1score, loss_train, loss_test, pearson, spearman ]

        #Delete all calculated results to free RAM
        del reconstruct_mat_train
        del reconstruct_mat_test
        del nmf_comp_train
        del nmf_comp_test
        del nmf_time
        del result_train
        del result_test
        del df2
        del test2
        
        i = i+1
      
    #Append results for each value of k (Used for plotting graphs)
    class_wise_loss_train.append(class_loss_train)
    k_loss_train.append(np.mean(class_loss_train))

    class_wise_loss_test.append(class_loss_test)
    k_loss_test.append(np.mean(class_loss_test))

    class_wise_pearson.append(class_pearson)

    class_wise_spearman.append(class_spearman)
# Out:
# 2, BRCA
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, LUAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, DLBC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, UCEC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, SKCM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, PRAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, HNSC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 2, KIRP
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, CESC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 2, THCA
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, KIRC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, STAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, COAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 2, READ
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, LGG
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 2, MESO
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, LAML
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, BLCA
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 2, OV
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, LUSC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, ACC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, THYM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, ESCA
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, PAAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, LIHC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, SARC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, GBM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, TGCT
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, KICH
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, PCPG
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, UCS
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, UVM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2, CHOL
# ...
#   ConvergenceWarning,
# 100, ACC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, THYM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, ESCA
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, PAAD
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, LIHC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, SARC
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, GBM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, TGCT
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, KICH
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, PCPG
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, UCS
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, UVM
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# 100, CHOL
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Print generated results df

# %%
results_df
# Out:
#     cancer_type  Full-data acc.  Full-data comp. time NMF components  \
# 0          BRCA        0.993671              6.906178              2
# 1          LUAD        0.988246              6.397125              2
# 2          DLBC        1.000000              4.486962              2
# 3          UCEC        0.989150              6.574579              2
# 4          SKCM        0.997288              7.086752              2
# ..          ...             ...                   ...            ...
# 193        KICH        0.994575              6.993820            100
# 194        PCPG        0.999096              5.209991            100
# 195         UCS        0.995479              6.644947            100
# 196         UVM        1.000000              4.477508            100
# 197        CHOL        0.998192              7.205182            100
#
#      NMF calc. time  NMF acc.  Precision    Recall   F1Score  \
# 0          0.031798  0.889693   0.889693  1.000000  0.941627
# 1          0.032758  0.948463   0.948463  1.000000  0.973550
# 2          0.033955  0.995479   0.995479  1.000000  0.997734
# 3          0.032975  0.949367   0.949367  1.000000  0.974026
# 4          0.031194  0.957505   0.957505  1.000000  0.978291
# ..              ...       ...        ...       ...       ...
# 193        0.071387  0.990958   0.998165  0.992701  0.995425
# 194        0.085201  0.999096   0.999081  1.000000  0.999540
# 195        0.070906  0.993671   0.994570  0.999091  0.996825
# 196        0.057802  1.000000   1.000000  1.000000  1.000000
# 197        0.065163  0.995479   0.995479  1.000000  0.997734
#
#      Train Reconstruction Loss  Test Reconstruction Loss  \
# 0                    49.012276                171.810960
# 1                    49.012276                171.810960
# 2                    49.012276                171.810960
# 3                    49.012276                171.810960
# 4                    49.012276                171.810960
# ..                         ...                       ...
# 193                  18.887964                102.371326
# 194                  18.883897                102.324553
# 195                  18.907939                102.541871
# 196                  18.876867                102.376411
# 197                  18.872715                102.311707
#
#                                          Pearson Coeff  \
# 0    [0.6690904024365792, 0.5551878254408148, 0.537...
# 1    [0.6244215913381145, 0.6641608553595486, 0.542...
# 2    [0.5825481187727412, 0.5897465860241771, 0.588...
# 3    [0.6333616988831645, 0.6559009656011082, 0.596...
# 4    [0.6418461518127109, 0.473473509661677, 0.6162...
# ..                                                 ...
# 193  [0.7451435295191218, 0.7820823294545763, 0.763...
# 194  [0.8068122465248498, 0.8570351502486941, 0.734...
# 195  [0.7946121446233778, 0.7606180921570329, 0.780...
# 196  [0.6975329576998042, 0.8214321411408452, 0.799...
# 197  [0.6929752304716909, 0.7929491876944138, 0.729...
#
#                                         Spearman Coeff
# 0    [0.7556780608768572, 0.7288871404916883, 0.705...
# 1    [0.7362334351305979, 0.7711988274020585, 0.685...
# 2    [0.7416862937813289, 0.7356230270760487, 0.704...
# 3    [0.7581805781418571, 0.7835456546319205, 0.777...
# 4    [0.7393122612864236, 0.6909390136649262, 0.761...
# ..                                                 ...
# 193  [0.8590425203854881, 0.8670820743947131, 0.859...
# 194  [0.8699912124226531, 0.9079834159793724, 0.836...
# 195  [0.8619097069773828, 0.8448805168836917, 0.864...
# 196  [0.8457690147882788, 0.8960741276983947, 0.880...
# 197  [0.8336227944197803, 0.8812620213618024, 0.842...
#
# [198 rows x 13 columns]

# %% [markdown]
# Print specfic results for k=50 to illustrate performance differences between classes

# %%
results_df.loc[results_df['NMF components']==int(50)]
# Out:
#     cancer_type  Full-data acc.  Full-data comp. time NMF components  \
# 132        BRCA        0.992767              6.802785             50
# 133        LUAD        0.988246              6.349514             50
# 134        DLBC        1.000000              4.520725             50
# 135        UCEC        0.989150              6.581450             50
# 136        SKCM        0.997288              6.951373             50
# 137        PRAD        1.000000              5.166851             50
# 138        HNSC        0.996383              6.479860             50
# 139        KIRP        0.995479              6.992617             50
# 140        CESC        0.991863              7.931732             50
# 141        THCA        1.000000              3.740153             50
# 142        KIRC        0.992767              6.664761             50
# 143        STAD        0.995479              6.478645             50
# 144        COAD        0.981013              6.737903             50
# 145        READ        0.982821              6.761722             50
# 146         LGG        0.996383              7.315869             50
# 147        MESO        1.000000              4.912652             50
# 148        LAML        1.000000              3.819948             50
# 149        BLCA        0.984629              6.438065             50
# 150          OV        0.999096              6.726109             50
# 151        LUSC        0.985533              6.380130             50
# 152         ACC        1.000000              4.419528             50
# 153        THYM        1.000000              5.873141             50
# 154        ESCA        0.991863              6.728965             50
# 155        PAAD        0.997288              7.084252             50
# 156        LIHC        0.995479              6.818521             50
# 157        SARC        0.998192              6.813895             50
# 158         GBM        0.999096              7.643621             50
# 159        TGCT        1.000000              5.379522             50
# 160        KICH        0.994575              6.896339             50
# 161        PCPG        0.999096              4.903228             50
# 162         UCS        0.995479              6.723517             50
# 163         UVM        1.000000              4.125833             50
# 164        CHOL        0.998192              7.311732             50
#
#      NMF calc. time  NMF acc.  Precision    Recall   F1Score  \
# 132        0.097898  0.994575   0.997963  0.995935  0.996948
# 133        0.083269  0.982821   0.998066  0.983794  0.990879
# 134        0.067228  0.996383   0.996380  1.000000  0.998187
# 135        0.081468  0.990958   0.995238  0.995238  0.995238
# 136        0.082037  0.995479   0.999053  0.996223  0.997636
# 137        0.080118  0.998192   0.998101  1.000000  0.999049
# 138        0.098194  0.965642   0.989362  0.974286  0.981766
# 139        0.100957  0.971971   0.971920  1.000000  0.985760
# 140        0.127798  0.981013   0.993446  0.986977  0.990201
# 141        0.064114  1.000000   1.000000  1.000000  1.000000
# 142        0.088034  0.989150   0.997115  0.991396  0.994247
# 143        0.094284  0.980108   0.995234  0.983977  0.989573
# 144        0.090554  0.976492   0.995197  0.980132  0.987607
# 145        0.086882  0.976492   0.993500  0.982553  0.987996
# 146        0.094777  0.991863   0.999044  0.992403  0.995712
# 147        0.055731  0.993671   0.994555  0.999088  0.996817
# 148        0.056795  1.000000   1.000000  1.000000  1.000000
# 149        0.089004  0.983725   0.987862  0.995296  0.991565
# 150        0.078207  0.994575   1.000000  0.994419  0.997201
# 151        0.103061  0.952080   0.994059  0.955281  0.974284
# 152        0.056026  1.000000   1.000000  1.000000  1.000000
# 153        0.057272  0.999096   1.000000  0.999086  0.999543
# 154        0.093337  0.967450   0.996223  0.970561  0.983225
# 155        0.070639  0.979204   0.990783  0.988051  0.989416
# 156        0.088291  0.996383   0.997186  0.999060  0.998122
# 157        0.079308  0.989150   1.000000  0.988889  0.994413
# 158        0.075310  0.993671   0.998158  0.995409  0.996782
# 159        0.061037  0.998192   0.999083  0.999083  0.999083
# 160        0.060063  0.993671   0.995450  0.998175  0.996811
# 161        0.060185  0.999096   0.999081  1.000000  0.999540
# 162        0.082280  0.994575   0.999088  0.995455  0.997268
# 163        0.054248  1.000000   1.000000  1.000000  1.000000
# 164        0.062478  0.995479   0.995479  1.000000  0.997734
#
#      Train Reconstruction Loss  Test Reconstruction Loss  \
# 132                  22.751137                111.704601
# 133                  22.779367                111.892746
# 134                  22.738580                111.774791
# 135                  22.747024                111.692470
# 136                  22.758671                111.653406
# 137                  22.759189                111.796999
# 138                  22.785253                111.826959
# 139                  22.753621                111.651766
# 140                  22.754631                111.699347
# 141                  22.755132                111.787205
# 142                  22.739644                111.614867
# 143                  22.741926                111.779631
# 144                  22.768073                111.650987
# 145                  22.769297                111.890707
# 146                  22.749245                111.757062
# 147                  22.797668                111.862420
# 148                  22.737893                111.680674
# 149                  22.788632                111.865390
# 150                  22.780218                111.719900
# 151                  22.752088                111.838076
# 152                  22.727842                111.628169
# 153                  22.797174                111.833658
# 154                  22.762480                111.724075
# 155                  22.757749                111.690021
# 156                  22.793860                111.918070
# 157                  22.805221                111.993267
# 158                  22.787902                111.709026
# 159                  22.737593                111.771862
# 160                  22.748026                111.604193
# 161                  22.761770                111.835814
# 162                  22.765133                111.711850
# 163                  22.748932                111.714370
# 164                  22.769465                111.844886
#
#                                          Pearson Coeff  \
# 132  [0.8404558237877802, 0.7783314915554022, 0.677...
# 133  [0.6989856096951674, 0.773147690096375, 0.7798...
# 134  [0.7072245983543277, 0.7401455712442853, 0.632...
# 135  [0.8040571102930856, 0.7533644211272142, 0.709...
# 136  [0.7048319523040688, 0.7320557584000529, 0.799...
# 137  [0.7495612527135757, 0.809855223162135, 0.7976...
# 138  [0.7633346132657339, 0.7483469794876493, 0.808...
# 139  [0.6884643491558567, 0.7655681951430413, 0.670...
# 140  [0.7088195408024351, 0.7696670762009483, 0.725...
# 141  [0.7529330098474507, 0.7419691246767148, 0.759...
# 142  [0.6883972558896165, 0.7725671743305148, 0.726...
# 143  [0.736276203444085, 0.7530143324672596, 0.8460...
# 144  [0.6601083571883927, 0.7750748310952724, 0.697...
# 145  [0.7518770538307661, 0.7707258304470309, 0.779...
# 146  [0.7965388198379215, 0.6273059707560775, 0.792...
# 147  [0.7515387957277866, 0.7399150920010401, 0.790...
# 148  [0.7490809160765506, 0.8131521572440046, 0.792...
# 149  [0.6733544374265158, 0.791664847341415, 0.6836...
# 150  [0.7382673045522022, 0.7318252911673766, 0.738...
# 151  [0.7629598195346893, 0.7720421004658895, 0.762...
# 152  [0.6603071157982505, 0.8341984196204064, 0.743...
# 153  [0.7625577780526492, 0.7593428230182434, 0.641...
# 154  [0.7065718280181223, 0.7546258739924603, 0.742...
# 155  [0.7648179768035609, 0.7415367374027385, 0.763...
# 156  [0.6858498359480598, 0.7798238616354647, 0.684...
# 157  [0.8341559721448943, 0.7420917121073131, 0.756...
# 158  [0.7251686903705058, 0.7270963293110604, 0.706...
# 159  [0.7964493011945191, 0.6895029195596405, 0.781...
# 160  [0.7619342204059855, 0.79516424640128, 0.71845...
# 161  [0.7623303448102791, 0.7102356066733749, 0.657...
# 162  [0.8338888652622222, 0.7173289902270523, 0.744...
# 163  [0.7437511141899122, 0.7059911782781103, 0.585...
# 164  [0.6758454751943785, 0.6552241632098292, 0.746...
#
#                                         Spearman Coeff
# 132  [0.9020572517079812, 0.8662705628833854, 0.809...
# 133  [0.8243841120623284, 0.8492148748490873, 0.863...
# 134  [0.8214792985110875, 0.8404784539031211, 0.794...
# 135  [0.8918844390815351, 0.8521662154602003, 0.831...
# 136  [0.833158656715257, 0.8431936874307543, 0.8897...
# 137  [0.8330912131011124, 0.8801144164886104, 0.883...
# 138  [0.861038966420639, 0.8428900517754124, 0.9015...
# 139  [0.8166754033906538, 0.866466578060554, 0.8074...
# 140  [0.8130912734486005, 0.8489548375415106, 0.841...
# 141  [0.8558023554450436, 0.8311841475423206, 0.852...
# 142  [0.7892004198641671, 0.8753430228015456, 0.825...
# 143  [0.8489669410565236, 0.8517874098947216, 0.903...
# 144  [0.7898401142513475, 0.8509003027199, 0.824480...
# 145  [0.84188287151832, 0.8641982575311562, 0.87700...
# 146  [0.8754030764964605, 0.787658837343321, 0.8694...
# 147  [0.8486862066738164, 0.8472251268143879, 0.874...
# 148  [0.8383731293265244, 0.8812678078358537, 0.860...
# 149  [0.8263988112838585, 0.8625800116698809, 0.811...
# 150  [0.8512353085778148, 0.8462003778045084, 0.855...
# 151  [0.845666702000499, 0.8533106131931241, 0.8660...
# 152  [0.7800321877313626, 0.9105045936784407, 0.869...
# 153  [0.8208024634836931, 0.8511965846557241, 0.795...
# 154  [0.8338762304481612, 0.8607157540803704, 0.856...
# 155  [0.8648174465788843, 0.8329635984387554, 0.853...
# 156  [0.8127959341932169, 0.8693969060636155, 0.823...
# 157  [0.9098339780652933, 0.8466542127237805, 0.861...
# 158  [0.8487701969437652, 0.8419481417065127, 0.798...
# 159  [0.8903042785633759, 0.8079164490628394, 0.878...
# 160  [0.855719889170064, 0.8900604378393633, 0.8404...
# 161  [0.8483858694006503, 0.8318569217700261, 0.806...
# 162  [0.9099590186359354, 0.8278921886410884, 0.835...
# 163  [0.8390494145862256, 0.8445269753869512, 0.766...
# 164  [0.8174975529784942, 0.7834675179743089, 0.839...

# %% [markdown]
# Store NMF Results in csv file

# %%
results_df.to_csv ('../results/NMF/nmf_accuracy_results.csv')

# %% [markdown]
# Plot overall test reconstruction loss vs num_comp graph

# %%
# plot the different graphs for reconstruction loss

plt.plot(num_latent_space, k_loss_test, label = "Test")

path = '../results/NMF/reconstuction_nmf'+'.png'

# naming the x axis
plt.xlabel('K')
# naming the y axis
plt.ylabel('Reconstruction Loss')

plt.title('Reconstruction Loss v/s Latent Space')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))

plt.savefig(path)
plt.legend()
plt.show()

# %%
# plot class wise reconstruction loss graph 
label=[]
for key in c_type_list:
    label.append(key)
class_wise_loss=np.array(class_wise_loss_test)
for ctype in range(len(c_type_list)):
    
    
    k_loss= class_wise_loss[:,ctype]
    plt.plot(num_latent_space, k_loss)

    # naming the x axis
    plt.xlabel('K Latent Dimensionality')
    # naming the y axis
    plt.ylabel('Reconstruction Loss')
    # giving a title to the graph
    plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    plt.title('Testing Loss v/s K for {}'.format(label[ctype]))

    plt.legend()
    plt.show()

# %% [markdown]
# For different values of k we obtain the pearson coeff create a box plot for each class

# %%
# plot class wise pearson correlation graph 
label=[]
for key in c_type_list:
    label.append(key)
class_wise_pearson=np.array(class_wise_pearson)

num_latent_space=np.array(num_latent_space)
c_pearson=[]

for j in range(0,len(c_type_list)):
    c_pearson=[]
    for i in range(0,len(num_latent_space)):
        a=class_wise_pearson[i][j]
        c_pearson.append(a)
        
    # plot the box plot of the calculated pearson values
    c_pearson= np.array(c_pearson)
    fig, ax = plt.subplots() 
    fig.suptitle('Box plot for '+ label[j]) 
    ax.set_xlabel('K Latent Dimensionality') 
    ax.set_ylabel('Pearson Correlation Coefficient') 
    ax.boxplot(np.transpose(c_pearson), labels= num_latent_space) 
    pearson_path = '../results/NMF/pearson_reconstuction_nmf'+str(j)+'.png'
    fig.savefig(pearson_path)

# %% [markdown]
# Similar to Pearson, for different values of k we obtain the pearson coeff create a box plot for each class

# %%
# plot class wise spearman correlation graph 
label=[]
for key in c_type_list:
    label.append(key)
class_wise_spearman=np.array(class_wise_spearman)

num_latent_space=np.array(num_latent_space)
c_spearman=[]

for j in range(0,len(c_type_list)):
    c_spearman=[]
    for i in range(0,len(num_latent_space)):
        a=class_wise_spearman[i][j]
        c_spearman.append(a)
        
    # plot the box plot of the calculated pearson values
    c_spearman= np.array(c_spearman)
    fig, ax = plt.subplots() 
    fig.suptitle('Box plot for '+ label[j]) 
    ax.set_xlabel('K Latent Dimensionality') 
    ax.set_ylabel('Spearman Correlation Coefficient') 
    ax.boxplot(np.transpose(c_spearman), labels= num_latent_space) 
    spearman_path = '../results/NMF/spearman_reconstuction_nmf'+str(j)+'.png'
    fig.savefig(spearman_path)

# %% [markdown]
# ## Multiclass Regression

# %% [markdown]
# Similar to function returnDf2, we define a function that returns label encoded dataframe with 33 classes

# %%
def multi_returnDf2(df, ind):
    '''
    df - input df to rename classes on (train_df or test_df)
    ind - either merge_trian or merge_test

    '''

    #drop sample_id (not needed as we have already appended the cancer type from labels)
    df2  = df.drop(['sample_id'], axis=1)

    le = LabelEncoder()
    df2['cancer_type'] = le.fit_transform(df2['cancer_type'])

    #Shuffle df2
    df2 = df2.sample(frac=1).reset_index(drop=True)

    return df2

# %% [markdown]
# Cell to perform NMF data compression on the input dataframe for different values of k - the number of reduced components for all classes

# %%
#obtain all the different values of cancer types
c_type_list = collections.Counter(merge_train)

#Columns of resultant dataframe, and create it
cols = ['Full-data acc.', 'Full-data comp. time', 'NMF components', 'NMF calc. time', 'NMF acc.','Precision', 'Recall', 'F1Score', 'Train Reconstruction Loss','Test Reconstruction Loss', 'Pearson Coeff', 'Spearman Coeff']

results_df_multi = pd.DataFrame(columns = cols)
i = 0

#List of different values of k
num_latent_space= [2,5,10,20,50,100]

#Define empty lists to hold results in
class_wise_loss_test_multi=[]

class_wise_loss_train_multi=[]

class_wise_pearson_multi=[]

class_wise_spearman_multi=[]

#Outer loop with number of reduced dimensions
for k in num_latent_space:

    print(str(k))
    # train_data
    df2 = multi_returnDf2(train_tcga_df, merge_train)
    #test data
    test2 = multi_returnDf2(test_tcga_df, merge_test)
    # run LR on Entire datasaet 
    accuracy, time_laps = runLR(df2, test2)

    result_train, result_test = NMF_scale(df2, test2)
    
    # calculate NMF and reconstruction 
    reconstruct_mat_train, reconstruct_mat_test, nmf_comp_train, nmf_comp_test, nmf_time = returnNMF(result_train, result_test, c_type, k)
    
    # get train test split
    train_x,test_x,train_y,test_y = prepNMFClassifier(df2, test2, nmf_comp_train, nmf_comp_test)
    
    # run LR on nmf components
    nmf_acc, nmf_time, precision, recall, f1score = NMFClassifier(train_x, train_y, test_x, test_y)

    #Calculate data reduction metrics
    loss_train=calc_reconstruct_loss(result_train, reconstruct_mat_train)
    class_wise_loss_train_multi.append(loss_train)

    loss_test=calc_reconstruct_loss(result_test, reconstruct_mat_test)
    class_wise_loss_test_multi.append(loss_test)

    pearson=calc_pearson(result_test, reconstruct_mat_test)
    class_wise_pearson_multi.append(pearson)

    spearman=calc_spearman(result_test, reconstruct_mat_test)
    class_wise_spearman_multi.append(spearman)
    
    #Append all results to dataframe
    results_df_multi.loc[i] = [accuracy,time_laps, nmf_comp_test.shape[1],nmf_time,  nmf_acc,precision, recall, f1score, loss_train, loss_test, pearson, spearman ]

    #Delete all calculated results to free RAM
    del reconstruct_mat_train
    del reconstruct_mat_test
    del nmf_comp_train
    del nmf_comp_test
    del nmf_time
    del result_train
    del result_test
    del df2
    del test2
    
    i = i+1

# %% [markdown]
# Print generated results df

# %%
results_df_multi
# Out:
#    Unnamed: 0  Full-data acc.  Full-data comp. time  NMF components  \
# 0           0        0.920434             65.290471               2
# 1           1        0.920434             59.894812               5
# 2           2        0.920434             61.604550              10
# 3           3        0.918626             59.823431              20
# 4           4        0.918626             60.330526              50
# 5           5        0.918626             60.701691             100
#
#    NMF calc. time  NMF acc.  Precision  Recall   F1Score  \
# 0        1.465876  0.150090   0.000000     0.0  0.000000
# 1        1.358746  0.315552   0.000000     0.0  0.000000
# 2        1.398844  0.585895   0.000000     0.0  0.000000
# 3        1.479517  0.756781   0.888889     1.0  0.941176
# 4        1.429399  0.883363   1.000000     1.0  1.000000
# 5        1.601363  0.896022   1.000000     1.0  1.000000
#
#    Train Reconstruction Loss  Test Reconstruction Loss  \
# 0                  49.012276                171.810960
# 1                  40.857266                153.369498
# 2                  34.787857                139.928432
# 3                  28.853508                125.752000
# 4                  22.765703                111.862327
# 5                  18.878466                102.391085
#
#                                        Pearson Coeff  \
# 0  [0.4736756810975763, 0.5761398544956351, 0.634...
# 1  [0.6074958926553179, 0.634385252774176, 0.6610...
# 2  [0.5756901425625243, 0.6409672885524211, 0.728...
# 3  [0.6553641939582383, 0.7210185883652767, 0.681...
# 4  [0.736698129178129, 0.7684367518254096, 0.7672...
# 5  [0.8233473280757315, 0.7988990726237422, 0.702...
#
#                                       Spearman Coeff
# 0  [0.6614684944250109, 0.7396424792766014, 0.739...
# 1  [0.7507194537994779, 0.7549038869041306, 0.776...
# 2  [0.7295022745892895, 0.7928204636403566, 0.842...
# 3  [0.7784015249109796, 0.8019913457115745, 0.807...
# 4  [0.8203585384778515, 0.8559434711592265, 0.863...
# 5  [0.8911044581404012, 0.8807235781988627, 0.848...

# %% [markdown]
# Store NMF Results in csv file

# %%
results_df_multi.to_csv ('../results/NMF/nmf_multi_accuracy_results.csv')

# %% [markdown]
# Plot Test reconstruction Loss vs num components

# %%
plt.plot(num_latent_space, class_wise_loss_test_multi, label = "Test")

path = '../results/NMF/reconstuction_nmf_multi'+'.png'


# naming the x axis
plt.xlabel('K')
# naming the y axis
plt.ylabel('Reconstruction Loss')

plt.title('Reconstruction Loss v/s Latent Space')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))

plt.savefig(path)
plt.legend()
plt.show()

# %% [markdown]
# For different values of k we obtain the pearson coeff and create a box plot

# %%
# plot class wise pearson correlation graph 

fig, ax = plt.subplots() 
fig.suptitle('Box plot') 
ax.set_xlabel('K Latent Dimensionality') 
ax.set_ylabel('Pearson Correlation Coefficient') 
ax.boxplot(np.transpose(class_wise_pearson_multi), labels= num_latent_space) 
pearson_path = '../results/NMF/pearson_reconstuction_nmf_multi'+ '.png'
fig.savefig(pearson_path)

# %% [markdown]
# For different values of k we obtain the spearman coeff and create a box plot

# %%
# plot class wise pearson correlation graph 

fig, ax = plt.subplots() 
fig.suptitle('Box plot') 
ax.set_xlabel('K Latent Dimensionality') 
ax.set_ylabel('Spearman Correlation Coefficient') 
ax.boxplot(np.transpose(class_wise_spearman_multi), labels= num_latent_space) 
spearman_path = '../results/NMF/spearman_reconstuction_nmf_multi'+ '.png'
fig.savefig(spearman_path)

# %% [markdown]
# Define and run function to generate scores-loading biplot

# %%
def myplot(score,coeff,labels=None):
    xs = score.iloc[:,0]
    ys = score.iloc[:,1]
    n = labels.shape[0]
    print(coeff.shape)
    coeff1 = coeff[:,0]
    coeff2 = coeff[:,1]
    scalecoeff1 = 1.0/(coeff1.max() - coeff1.min())
    scalecoeff2 = 1.0/(coeff2.max() - coeff2.min())
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    idx = ((xs*scalex)**2+ (ys*scaley)**2)>0.05
    xs_new= xs[idx]
    ys_new= ys[idx]
    plt.scatter(xs_new * scalex,ys_new * scaley, s=2)
    
    for i in range(n):
        if ((abs(xs[i]*scalex)>0.4) or (abs(ys[i]*scaley) >0.3)):
            plt.arrow(0, 0, coeff[i,0]*scalecoeff1, coeff[i,1]*scalecoeff2,color = 'r',alpha = 0.5)
            if labels is None:
                plt.text(coeff[i,0]* scalecoeff1, coeff[i,1] * scalecoeff2, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
            else:
                plt.text(coeff[i,0]* scalecoeff1, coeff[i,1] * scalecoeff2, labels[i], color = 'g', ha = 'center', va = 'center')

    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()


myplot(nmf_comp_test.iloc[:,0:2], np.transpose(nmf_model.components_[0:2,:]),test_y)
plt.show()
# biplot(ica_comp_test[:,0:2], np.transpose(ica.components_[0:2, :]),test_y)
# Out:
# (16147, 2)
